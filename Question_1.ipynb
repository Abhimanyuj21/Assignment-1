# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.datasets import load_iris

# %%
iris = load_iris()
data = iris.data
feature_names = iris.feature_names

# %%
for i in range(data.shape[1]):
    plt.figure(figsize=(6, 4))
    plt.hist(data[:, i], bins=20, color='skyblue', edgecolor='black')
    plt.xlabel(feature_names[i])
    plt.ylabel('Frequency')
    plt.title('Histogram of ' + feature_names[i])
    plt.show()

# %%
plt.figure(figsize=(12, 6))
for i in range(data.shape[1]):
    for j in range(i+1, data.shape[1]):
        plt.scatter(data[:, i], data[:, j], label=f"{feature_names[i]} vs {feature_names[j]}")

# %%
plt.xlabel(feature_names[i])
plt.ylabel(feature_names[j])
plt.title('Scatter plot between different features')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print("Summary statistics for numerical columns:")
for col, stats_dict in stats_summary.items():
    print(col)
    for stat, value in stats_dict.items():
        print(f"{stat}: {value}")
    print()
# Out:
# Summary statistics for numerical columns:
